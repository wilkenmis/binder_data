# %%
#HY
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5],[688.73, 689.52, 697.23, 697.60, 701.44],'o', label = 'EOM-CC/nox2c')
plt.plot([1, 2, 3, 4, 5],[688.62, 689.41, 697.12, 697.49, 701.33], 'o', label = 'EOM-CC/x2c')
plt.ylabel('Energy (eV)')
plt.xlabel('Transition')
plt.legend()
plt.title("First excited states in the fluoride K-shell")
plt.show()

import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5],[2828.59, 2828.97, 2834.36, 2834.37, 2841.66],'o', label = 'EOM-CC/nox2c')
plt.plot([1, 2, 3, 4, 5],[2827.74, 2828.12, 2833.51, 2833.52, 2840.80], 'o', label = 'EOM-CC/x2c')
plt.ylabel('Energy (eV)')
plt.xlabel('Transition')
plt.legend()
plt.title("First excited states in the chloride K-shell")
plt.show()

import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5],[13507.57, 13507.75, 13513.85, 13513.86, 13520.3],'o', label = 'EOM-CC/nox2c')
plt.plot([1, 2, 3, 4, 5],[13499.09, 13499.27, 13505.37, 13506.00, 13511.86], 'o', label = 'EOM-CC/x2c')
plt.ylabel('Energy (eV)')
plt.xlabel('Transition')
plt.legend()
plt.title("First excited states in the bromine K-shell")
plt.show()

# %%
#H2X
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5],[535.35, 536.14, 537.21, 537.21, 544.12],'o', label = 'EOM-CC/nox2c')
plt.plot([1, 2, 3, 4, 5],[535.28, 536.07, 537.14, 537.14, 544.04], 'o', label = 'EOM-CC/x2c')
plt.ylabel('Energy (eV)')
plt.xlabel('Transition')
plt.legend()
plt.title("First excited states in the oxygen K-shell")
plt.show()

import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4, 5],[2477.29, 2477.29, 2477.96, 2478.36, 2483.39],'o', label = 'EOM-CC/nox2c')
plt.plot([1, 2, 3, 4, 5],[2476.59, 2476.59, 2477.26, 2477.66, 2482.69], 'o', label = 'EOM-CC/x2c')
plt.ylabel('Energy (eV)')
plt.xlabel('Transition')
plt.legend()
plt.title("First excited states in the sulfur K-shell")
plt.show()
